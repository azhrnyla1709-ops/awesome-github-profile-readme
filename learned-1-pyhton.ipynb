# %% [markdown]
# <a href="https://colab.research.google.com/github/azhrnyla1709-ops/awesome-github-profile-readme/blob/master/learned-1-pyhton.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
materi pertama pembelajaran tentang pyhton

# %%
a=2
b=3
c=a+b
print (c)
# Out:
# 5
